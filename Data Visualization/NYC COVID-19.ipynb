# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# path where the datasets are placed
file1 = (r'C:\Users\npsom\Documents\Moomoo\MIT COVID-19 Datathon\Data Wrangling\Newboro.csv')
file2 = (r'C:\Users\npsom\Documents\Moomoo\MIT COVID-19 Datathon\Data Wrangling\by-age.csv')
file3 = (r'C:\Users\npsom\Documents\Moomoo\MIT COVID-19 Datathon\Data Wrangling\by-sex.csv')

df1 = pd.read_csv(file1,index_col=0)
df2 = pd.read_csv(file2)
df3 = pd.read_csv(file3)
df1.head()
#df1.info()
# Out:
#                COVID_CASE_COUNT  COVID_CASE_RATE
# BORO
# The Bronx                 41953          2851.87
# Brooklyn                  50436          1856.86
# Manhattan                 22889          1219.31
# Queens                    57178          2289.86
# Staten Island             12749          2536.66

# %%
sns.set(style="whitegrid")

g = sns.barplot(x=df1['BORO'], y=df1['COVID_CASE_COUNT'],
                data=df1, palette="muted")
g.set_yscale("log")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BORO'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-0666b4ca01af> in <module>
#       1 sns.set(style="whitegrid")
#       2
# ----> 3 g = sns.barplot(x=df1['BORO'], y=df1['COVID_CASE_COUNT'],
#       4                 data=df1, palette="muted")
#       5 g.set_yscale("log")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BORO'

# %%
df2.head()
# Out:
#             AGE_GROUP  COVID_CASE_RATE  HOSPITALIZED_CASE_RATE  DEATH_RATE
# 0          0-17 years           271.58                   22.70        0.52
# 1         18-44 years          2015.77                  220.38       17.84
# 2         45-64 years          3290.15                  815.74      166.00
# 3         65-74 years          3293.58                 1581.28      541.83
# 4  75 and older years          3932.36                 2496.82     1356.37

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   AGE_GROUP               6 non-null      object
#  1   COVID_CASE_RATE         6 non-null      float64
#  2   HOSPITALIZED_CASE_RATE  6 non-null      float64
#  3   DEATH_RATE              6 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 320.0+ bytes

# %%
sns.set(style="whitegrid")

g = sns.barplot(x=df2['AGE_GROUP'], y=df2['COVID_CASE_RATE'], data=df2, palette="muted")
palette = sns.xkcd_palette(["light blue grey", "pale gold", "rose pink"])
#g.set_yscale("log")
g.set_ylim(100, 4000)
g.set_xticklabels(g.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
g = sns.barplot(x=df2['AGE_GROUP'], y= df2['HOSPITALIZED_CASE_RATE'], data=df2, palette="muted")
palette = sns.xkcd_palette(["light blue grey", "pale gold", "rose pink"])
#g.set_yscale("log")
g.set_ylim(100, 4000)
g.set_xticklabels(g.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
g = sns.barplot(x=df2['AGE_GROUP'], y=df2['DEATH_RATE'],data=df2, palette="muted")
palette = sns.xkcd_palette(["light blue grey", "pale gold", "rose pink"])
#g.set_yscale("log")
g.set_ylim(100, 4000)
g.set_xticklabels(g.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
g = sns.barplot(x=df2['AGE_GROUP'], y= df2['HOSPITALIZED_CASE_RATE'], data=df2, palette="muted")
palette = sns.xkcd_palette(["light blue grey", "pale gold", "rose pink"])
#g.set_yscale("log")
g.set_ylim(100, 4000)
g.set_xticklabels(g.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
df3.head()
# Out:
#         SEX_GROUP  COVID_CASE_RATE  HOSPITALIZED_CASE_RATE  DEATH_RATE
# 0          Female          2043.22                  481.15      135.70
# 1            Male          2378.35                  701.35      229.93
# 2  Citywide total          2205.16                  587.08      181.37

# %%
df3['SEX_GROUP'].hist()

# %%
#p = sns.countplot(data=df2,
                 # x = df2['AGE_GROUP']
                  #)

sns.set(style="darkgrid")
ax = sns.countplot(x=df3['SEX_GROUP'],hue =  data=df3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-933ed3aa9a26> in <module>
#       4
#       5 sns.set(style="darkgrid")
# ----> 6 ax = sns.countplot(x=df3['SEX_GROUP'], y = df3['DEATH_RATE'], data=df3)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3546         y = x
#    3547     elif x is not None and y is not None:
# -> 3548         raise TypeError("Cannot pass values for both `x` and `y`")
#    3549     else:
#    3550         raise TypeError("Must pass values for either `x` or `y`")
#
# TypeError: Cannot pass values for both `x` and `y`

# %%
df2['AGE_GROUP'].hist()

# %%
df2 = pd.melt(df2, id_vars=['AGE_GROUP'], value_vars=[['COVID_CASE_RATE'],['HOSPITALIZED_CASE_RATE'],['DEATH_RATE']]

sns.factorplot(x='AGE_GROUP', y= [['COVID_CASE_RATE'],['HOSPITALIZED_CASE_RATE'],['DEATH_RATE']], data=df2, kind='bar')
# Out:
#   File "<ipython-input-78-e77930cbf703>", line 3
#     sns.factorplot(x='AGE_GROUP', y= [['COVID_CASE_RATE'],['HOSPITALIZED_CASE_RATE'],['DEATH_RATE']], data=df2, kind='bar')
#       ^
# SyntaxError: invalid syntax
